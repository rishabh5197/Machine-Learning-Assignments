# %% [markdown]
# # Name :- Rishabh Sharma
# # Registration Number :- 20MAI0082
# # DA-1

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
import requests
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Using Web Scraping to collect the data

# %%
while True:
    try:
        link = 'https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
        print(link)
        page = requests.get(link)
        print(page)
        break
    except:
        pass
# Out:
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# <Response [200]>

# %%
soup = bs(page.content,'html.parser')

# %%
# items = soup.find_all('div',class_="_4rR01T")
# items=[i.get_text() for i in items]
# items = [i.split(" - (")[0] for i in items]

# %%
details = soup.find_all("li",class_="rgWa7D")
details = [i.get_text() for i in details]

# %%
lis,newlis=[],[]
for i in details:
    if ("Intel ")in i or ("AMD ") in i or ("M1") in i :
        if newlis:
            lis.append(newlis)
            newlis=[]
            newlis.append(i)
        else:
            newlis.append(i)
    else:
        newlis.append(i)
newlisnew=[]
for i in lis:
    newlisnew.append(" ".join(i))

# %%
items = []
for i in newlisnew:
    if ' GB DDR4' in i:
         items.append(i.split(" GB DDR4")[0][:-2])
    elif ' GB DDR3' in i:
        items.append(i.split(" GB DDR3")[0][:-2] )
    elif ' GB LPDDR4X' in i:
        items.append(i.split(" GB LPDDR4X")[0][:-2] )
    else:
        items.append("")
company = [i.split()[0] for i in items]

# %%
pages= soup.find_all('a',class_='ge-49M',href=True)
pages = [str(i).split(">")[0][31:] for i in pages ]

# %%
ratings = soup.find_all("div",class_='_3LWZlK')
ratings = [i.get_text() for i in ratings]

# %%
prices =  soup.find_all("div",class_="_30jeq3 _1_WHN1")
prices = [i.get_text().replace("₹","").replace(",","") for i in prices]

# %%
# details = soup.find_all("li",class_="rgWa7D")
# details = [i.get_text() for i in details]

# %%
# indepth_link = soup.find_all("a",class_ = '_1fQZEK')

# %%
# start= str(indepth_link[0]).index("href=")
# end = str(indepth_link[0]).index(" rel=")
# links = ['https://www.flipkart.com'+str(str(i)[start+6:end-1]) for i in indepth_link]

# %%
lis,newlis=[],[]
for i in details:
    if ("Intel ")in i or ("AMD ") in i or ("M1") in i :
        if newlis:
            lis.append(newlis)
            newlis=[]
            newlis.append(i)
        else:
            newlis.append(i)
    else:
        newlis.append(i)
newlisnew=[]
for i in lis:
    newlisnew.append(" ".join(i))

# %% [markdown]
# ### Collecting data and filtering everything

# %%
processor_brand=[]
processor = []
ram = []
ram_type=[]
os =[]
screen_size=[]
ssd_present=[]
ssd_capacity=[]
hdd_capacity=[]
# count=0
for i in newlisnew:
    if "Intel " in i:
#         print(count)
        processor_brand.append("Intel")
        processor.append(i.split()[1]+" "+i.split()[2])
    elif 'AMD' in i:
#         print(count)
        processor_brand.append("AMD")
        processor.append(i.split()[1]+" "+i.split()[2])
    elif "M1" in i:
#         print(count)
        processor_brand.append("M1")
        processor.append(i.split()[1]+" "+i.split()[2])
    else:
        processor_brand.append("")
        processor.append("")
#     count+=1
    if ' GB DDR4 RAM' in i:
        index = i.index(' GB DDR4 RAM')
        ram.append(i[index-2:index])
        ram_type.append("DDR4")
    elif  ' GB DDR3' in i:
        index = i.index(' GB DDR3 RAM')
        ram.append(i[index-2:index])
        ram_type.append("DDR3")
    else:
        ram.append("")
    if ' Operating System' in i:
        a = i.split()
        index = a.index("Operating")
        if a[index-1]=="10":
                os.append("Windows 10")
        elif a[index-2]=='Mac':
            os.append("Mac Os")
        else:
            os.append(a[index-1])
    else:
        os.append("")
    if "inch" in i:
        a = i.split()
        if 'inches)' in a:
            index = a.index("inches)")
        else:
            index = a.index("inch)")
        screen_size.append(a[index-1].strip("(")+" inch")
    if (" GB SSD" in i) or (" TB SSD" in i):
        ssd_present.append("Yes")
        if " GB SSD" in i:
            start = i.index(" GB SSD")-3
            end=i.index(" GB SSD")
            ssd_capacity.append(i[start:end])
        elif' TB SSD' in i:
            index = i.index(" TB SSD")
            ssd_capacity.append(int(i[index-1])*1024)
    else:
        ssd_present.append("No")
        ssd_capacity.append("")
    if " HDD" in i:
        index = i.index(" HDD")
        hdd_capacity.append(i[index-4])
    else:
        hdd_capacity.append("")

# %% [markdown]
# ### Creating a dataframe in order to carry out further steps

# %%
data = pd.DataFrame({
'items':items[:len(processor)],                                       # Name of Laptop
'company':company[:len(processor)],                              # Company of laptop  (or Laptop belongs to which company)                       (Categorical)
'ratings out of 5':ratings[:len(processor)],                     # What are the rating mentioned overall to the device  (continous)
'prices':prices[:len(processor)],                                     # Price of the laptop                                                       (continous)
'processor_brand':processor_brand,                             # what is the processor of the laptop this will be categorical as Intel or AMD (Categorical)
'processor':processor,                                                   # Type of processor of the laptop (Categorical)
'ram':ram ,                                                                     # how much ram does it have (Categorical)
'ram_type':ram_type,                                                    # what is the type of ram (Categorical)
'operating_system' :os,                                                  # consist of which operating system by default (Categorical)
'screen_size':screen_size,                                             # Screen-size of the laptop (Categorical)
'ssd_present':ssd_present,                                            # is SSD present in the laptop (Categorical)
'ssd_capacity':ssd_capacity,                                          # What is the capacity of the SSD (continous)
'hdd_capacity_in_TB':hdd_capacity,                              # What is the capacity of HDD (Categorical)
'Purchased': [np.random.choice(["No","Yes"]) for i in range(0,len(processor))]})   # this is generated randomly whether the customer will buy a laptop or not.
data.to_csv("Dataset.csv",index=False)                                                                    # Storing data into csv file

# %%
data.shape
# Out:
# (23, 14)

# %%
data =data.replace("",np.nan)

# %%
data
# Out:
#                                         items company ratings out of 5 prices  \
# 0   AMD Ryzen 5 Quad Core Processor (3rd Gen)     AMD              4.4  48990
# 1          Intel Core i3 Processor (10th Gen)   Intel                4  35990
# 2          Intel Core i3 Processor (10th Gen)   Intel              4.2  35990
# 3           Intel Core i5 Processor (9th Gen)   Intel              4.5  52990
# 4          Intel Core i5 Processor (10th Gen)   Intel              4.1  42990
# 5             AMD Ryzen 5 Hexa Core Processor     AMD              4.5  54990
# 6          Intel Core i3 Processor (10th Gen)   Intel              4.2  33490
# 7                          Apple M1 Processor   Apple              4.6  92900
# 8             AMD Ryzen 5 Hexa Core Processor     AMD              4.3  65990
# 9              AMD APU Dual Core A6 Processor     AMD                4  24990
# 10         Intel Core i5 Processor (10th Gen)   Intel              4.3  49990
# 11         Intel Core i5 Processor (10th Gen)   Intel              4.5  49990
# 12         Intel Core i5 Processor (10th Gen)   Intel              4.2  60990
# 13            AMD Ryzen 5 Quad Core Processor     AMD              4.6  49990
# 14            AMD Ryzen 5 Hexa Core Processor     AMD              4.5  59990
# 15        Intel Core i7 Processor (11th Gen)    Intel              4.3  79990
# 16         Intel Core i5 Processor (10th Gen)   Intel              4.4  51990
# 17            AMD Ryzen 5 Quad Core Processor     AMD              4.4  50990
# 18         Intel Core i3 Processor (10th Gen)   Intel              4.2  38199
# 19          Intel Celeron Dual Core Processor   Intel              4.1  23990
# 20         Intel Core i5 Processor (10th Gen)   Intel              4.9  44990
# 21         Intel Core i3 Processor (11th Gen)   Intel                4  47990
# 22         Intel Core i5 Processor (10th Gen)   Intel              4.7  42990
#
#    processor_brand     processor ram ram_type operating_system screen_size  \
# 0              AMD       Ryzen 5   8     DDR4       Windows 10     14 inch
# 1            Intel       Core i3   8     DDR4       Windows 10   15.6 inch
# 2            Intel       Core i3   8     DDR4       Windows 10     14 inch
# 3            Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 4            Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 5              AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 6            Intel       Core i3   4     DDR4       Windows 10   15.6 inch
# 7               M1  M1 Processor   8     DDR4           Mac Os   13.3 inch
# 8              AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 9              AMD      APU Dual   4     DDR4       Windows 10   15.6 inch
# 10           Intel       Core i5   8     DDR4       Windows 10     14 inch
# 11           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 12           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 13             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 14             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 15           Intel       Core i7  16     DDR4       Windows 10     14 inch
# 16           Intel       Core i5   8     DDR4       Windows 10     14 inch
# 17             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 18           Intel       Core i3   8     DDR4       Windows 10     14 inch
# 19           Intel  Celeron Dual   4     DDR4       Windows 10   15.6 inch
# 20           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 21           Intel       Core i3   8     DDR4       Windows 10     14 inch
# 22           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
#
#    ssd_present ssd_capacity hdd_capacity_in_TB Purchased
# 0          Yes          256                  1       Yes
# 1          Yes          256                NaN       Yes
# 2          Yes          256                NaN        No
# 3          Yes          512                NaN        No
# 4           No          NaN                  1       Yes
# 5          Yes          512                NaN        No
# 6          Yes          256                NaN       Yes
# 7          Yes          256                NaN        No
# 8          Yes          512                NaN       Yes
# 9           No          NaN                  1        No
# 10         Yes         1024                NaN        No
# 11         Yes          512                NaN        No
# 12         Yes          256                  1        No
# 13          No          NaN                  1        No
# 14         Yes          256                  1       Yes
# 15         Yes         1024                NaN       Yes
# 16         Yes          256                  1        No
# 17         Yes          512                NaN       Yes
# 18         Yes          256                NaN       Yes
# 19         Yes          256                NaN       Yes
# 20          No          NaN                  1       Yes
# 21         Yes          256                NaN        No
# 22          No          NaN                  1        No

# %%
data.isnull().sum()
# Out:
# items                  0
# company                0
# ratings out of 5       0
# prices                 0
# processor_brand        0
# processor              0
# ram                    0
# ram_type               0
# operating_system       0
# screen_size            0
# ssd_present            0
# ssd_capacity           5
# hdd_capacity_in_TB    14
# Purchased              0
# dtype: int64

# %% [markdown]
# ### Filling null values

# %%
data = data.replace(np.nan,0)
data
# Out:
#                                         items company ratings out of 5 prices  \
# 0   AMD Ryzen 5 Quad Core Processor (3rd Gen)     AMD              4.4  48990
# 1          Intel Core i3 Processor (10th Gen)   Intel                4  35990
# 2          Intel Core i3 Processor (10th Gen)   Intel              4.2  35990
# 3           Intel Core i5 Processor (9th Gen)   Intel              4.5  52990
# 4          Intel Core i5 Processor (10th Gen)   Intel              4.1  42990
# 5             AMD Ryzen 5 Hexa Core Processor     AMD              4.5  54990
# 6          Intel Core i3 Processor (10th Gen)   Intel              4.2  33490
# 7                          Apple M1 Processor   Apple              4.6  92900
# 8             AMD Ryzen 5 Hexa Core Processor     AMD              4.3  65990
# 9              AMD APU Dual Core A6 Processor     AMD                4  24990
# 10         Intel Core i5 Processor (10th Gen)   Intel              4.3  49990
# 11         Intel Core i5 Processor (10th Gen)   Intel              4.5  49990
# 12         Intel Core i5 Processor (10th Gen)   Intel              4.2  60990
# 13            AMD Ryzen 5 Quad Core Processor     AMD              4.6  49990
# 14            AMD Ryzen 5 Hexa Core Processor     AMD              4.5  59990
# 15        Intel Core i7 Processor (11th Gen)    Intel              4.3  79990
# 16         Intel Core i5 Processor (10th Gen)   Intel              4.4  51990
# 17            AMD Ryzen 5 Quad Core Processor     AMD              4.4  50990
# 18         Intel Core i3 Processor (10th Gen)   Intel              4.2  38199
# 19          Intel Celeron Dual Core Processor   Intel              4.1  23990
# 20         Intel Core i5 Processor (10th Gen)   Intel              4.9  44990
# 21         Intel Core i3 Processor (11th Gen)   Intel                4  47990
# 22         Intel Core i5 Processor (10th Gen)   Intel              4.7  42990
#
#    processor_brand     processor ram ram_type operating_system screen_size  \
# 0              AMD       Ryzen 5   8     DDR4       Windows 10     14 inch
# 1            Intel       Core i3   8     DDR4       Windows 10   15.6 inch
# 2            Intel       Core i3   8     DDR4       Windows 10     14 inch
# 3            Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 4            Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 5              AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 6            Intel       Core i3   4     DDR4       Windows 10   15.6 inch
# 7               M1  M1 Processor   8     DDR4           Mac Os   13.3 inch
# 8              AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 9              AMD      APU Dual   4     DDR4       Windows 10   15.6 inch
# 10           Intel       Core i5   8     DDR4       Windows 10     14 inch
# 11           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 12           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 13             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 14             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 15           Intel       Core i7  16     DDR4       Windows 10     14 inch
# 16           Intel       Core i5   8     DDR4       Windows 10     14 inch
# 17             AMD       Ryzen 5   8     DDR4       Windows 10   15.6 inch
# 18           Intel       Core i3   8     DDR4       Windows 10     14 inch
# 19           Intel  Celeron Dual   4     DDR4       Windows 10   15.6 inch
# 20           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
# 21           Intel       Core i3   8     DDR4       Windows 10     14 inch
# 22           Intel       Core i5   8     DDR4       Windows 10   15.6 inch
#
#    ssd_present ssd_capacity hdd_capacity_in_TB Purchased
# 0          Yes          256                  1       Yes
# 1          Yes          256                  0       Yes
# 2          Yes          256                  0        No
# 3          Yes          512                  0        No
# 4           No            0                  1       Yes
# 5          Yes          512                  0        No
# 6          Yes          256                  0       Yes
# 7          Yes          256                  0        No
# 8          Yes          512                  0       Yes
# 9           No            0                  1        No
# 10         Yes         1024                  0        No
# 11         Yes          512                  0        No
# 12         Yes          256                  1        No
# 13          No            0                  1        No
# 14         Yes          256                  1       Yes
# 15         Yes         1024                  0       Yes
# 16         Yes          256                  1        No
# 17         Yes          512                  0       Yes
# 18         Yes          256                  0       Yes
# 19         Yes          256                  0       Yes
# 20          No            0                  1       Yes
# 21         Yes          256                  0        No
# 22          No            0                  1        No

# %% [markdown]
# ### Using train test split and selecting features

# %%
from sklearn.model_selection import train_test_split
x = data.drop(["items",'Purchased'],axis=1)
y = data[["Purchased"]]

# %% [markdown]
# ### Transforming string to numeric

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x["company"] = le.fit_transform(x["company"])
x["processor_brand"] = le.fit_transform(x["processor_brand"])
x["processor"] = le.fit_transform(x["processor"])
x["ram_type"] = le.fit_transform(x["ram_type"])
x["operating_system"] = le.fit_transform(x["operating_system"])
x["screen_size"] = le.fit_transform(x["screen_size"])
x["ssd_present"] = le.fit_transform(x["ssd_present"])
y["Purchased"] = le.fit_transform(y["Purchased"])

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,shuffle=True,test_size=0.1)

# %% [markdown]
# ### Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(xtrain,ytrain)
predictions = lr.predict(xtest)

# %%
predictions
# Out:
# array([0, 1, 1])

# %% [markdown]
# ### Using Confusion Matrix and accuracy score to find how much better the algorithm performs

# %%
from sklearn.metrics import accuracy_score,plot_confusion_matrix
plot_confusion_matrix(lr,xtest,ytest)

# %%
accuracy_score(predictions,ytest)
# Out:
# 1.0
